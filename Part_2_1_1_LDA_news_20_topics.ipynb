# %% [markdown]
# ## import packages

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
# ## remove stopwords
# ## we will replace this word list with our own list

# %%
#Prepare Stopwords
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# stop_words.extend(['from', 'subject', 're', 'edu', 'use','na', 'la', 'ooh', 'oh', 'ah', 'ba', 'da', 'aye','be',
#                  'go','get','know','s'])

# %% [markdown]
# ## import data

# %%
# Import Dataset
df = pd.read_csv('./cleaned_data/NewYorkTimes_CoverStory_2001-2015_SAMPLED.csv',sep=',')
df
# Out:
#         News_id  Year                                              Title  \
# 0       5158739  2001                                   long battle seen
# 1       5210808  2001                   pilots ask permission carry guns
# 2       5491991  2001                grief echoes new york santo domingo
# 3       4056314  2001  exaide bin laden describes terror campaign aim...
# 4       5240343  2001      new push get bin laden agree quit afghanistan
# ...         ...   ...                                                ...
# 1461  109431501  2015                  lobbyist sixfigure government job
# 1462  108686749  2015   physician pushed boundaries bring vitro birth us
# 1463  102260584  2015                  pastors son runs faith iowa nears
# 1464  103737745  2015         hacking exposed million us government says
# 1465  103447289  2015         obama scorns racism soaring singing eulogy
#
#                                                Abstract
# 0     focuses declaration war made united states pre...
# 1     reports air line pilots association largest pi...
# 2     focuses response dominicans americans crash am...
# 3     discusses testimony jamal ahmed alfadl secret ...
# 4     reports taliban government afghanistan announc...
# ...                                                 ...
# 1461  article discusses former us government agency ...
# 1462  obituary physician howard w jones jr noted wor...
# 1463  article discusses wisconsin governor scott wal...
# 1464  article announces million people impacted hack...
# 1465  article discusses eulogy delivered us presiden...
#
# [1466 rows x 4 columns]

# %%
# Convert to list
data = df.Abstract.tolist()
#pprint(data[:1])

# %% [markdown]
# Tokenize words and Clean-up text
# - tokenize each sentence into a list of words, removing punctuations and unnecessary characters altogether.
# - Gensim’s simple_preprocess() is great for this. Additionally I have set deacc=True to remove the punctuations.

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

#print(data_words[:1])

# %% [markdown]
# Creating Bigram and Trigram Models
# Bigrams are two words frequently occurring together in the document. Trigrams are 3 words frequently occurring.Some examples in our example are: ‘front_bumper’, ‘oil_leak’, ‘maryland_college_park’ etc.
# - Gensim’s Phrases model can build and implement the bigrams, trigrams, quadgrams and more. The two important arguments to Phrases are min_count and threshold.
# - The higher the values of these param, the harder it is for words to be combined to bigrams.

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
#print(trigram_mod[bigram_mod[data_words[0]]])

# %% [markdown]
# Remove Stopwords, Make Bigrams and Lemmatize
# - define the functions to remove the stopwords, make bigrams and lemmatization and call them sequentially.

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
#print(stop_words)
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB','ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# teststr = "hi be be make hi",'hi','hihihi'
# cleaned=remove_stopwords(teststr)
# cleaned

# %%
print(type(data_words))
print(len(data_words))
# Out:
# <class 'list'>
# 1466

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ','ADV','VERB'])

#print(data_lemmatized[:1])

# %% [markdown]
# Create the Dictionary and Corpus needed for Topic Modeling
# The two main inputs to the LDA topic model are the dictionary(id2word) and the corpus. Let’s create them.

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
#print(corpus[:1])

# %% [markdown]
# View a human-readable form of the corpus itself

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('bush', 1),
#   ('campaign', 1),
#   ('center', 1),
#   ('focus', 1),
#   ('forceful', 1),
#   ('laden', 1),
#   ('language', 1),
#   ('long', 1),
#   ('make', 1),
#   ('mention', 1),
#   ('military', 1),
#   ('nation', 1),
#   ('national', 1),
#   ('occur', 1),
#   ('prepare', 1),
#   ('prime', 1),
#   ('reflect', 1),
#   ('remark', 1),
#   ('response', 1),
#   ('statement', 1),
#   ('support', 1),
#   ('suspect', 1),
#   ('terrorism', 2),
#   ('terrorist_attack', 1),
#   ('war', 1)]]

# %% [markdown]
# In addition to the corpus and dictionary, you need to provide the number of topics.
#
# - Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# - chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the 20 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.072*"former" + 0.057*"federal" + 0.049*"case" + 0.038*"republican" + '
#   '0.033*"several" + 0.028*"vote" + 0.028*"highlight" + 0.027*"candidate" + '
#   '0.027*"business" + 0.026*"black"'),
#  (1,
#   '0.076*"religious" + 0.043*"employee" + 0.042*"immigrant" + 0.038*"medical" '
#   '+ 0.031*"rather" + 0.030*"longterm" + 0.022*"stem" + 0.021*"clinic" + '
#   '0.020*"cell" + 0.015*"disclosure"'),
#  (2,
#   '0.070*"government" + 0.048*"political" + 0.041*"make" + 0.038*"american" + '
#   '0.037*"military" + 0.036*"country" + 0.032*"leader" + 0.032*"official" + '
#   '0.031*"regard" + 0.025*"group"'),
#  (3,
#   '0.076*"program" + 0.059*"part" + 0.057*"announce" + 0.047*"television" + '
#   '0.036*"travel" + 0.036*"future" + 0.028*"site" + 0.027*"night" + '
#   '0.026*"deliver" + 0.026*"previous"'),
#  (4,
#   '0.062*"spending" + 0.056*"economy" + 0.036*"growth" + 0.034*"world" + '
#   '0.032*"likely" + 0.031*"receive" + 0.029*"global" + 0.028*"reduce" + '
#   '0.026*"still" + 0.023*"profit"'),
#  (5,
#   '0.063*"campaign" + 0.051*"also" + 0.050*"law" + 0.032*"look" + 0.032*"fund" '
#   '+ 0.028*"charge" + 0.026*"end" + 0.025*"bill" + 0.025*"leave" + '
#   '0.023*"state"'),
#  (6,
#   '0.100*"include" + 0.038*"report" + 0.032*"discusse" + 0.026*"use" + '
#   '0.024*"effort" + 0.022*"increase" + 0.021*"well" + 0.021*"impact" + '
#   '0.019*"company" + 0.019*"state"'),
#  (7,
#   '0.078*"present" + 0.057*"woman" + 0.033*"meeting" + 0.031*"reach" + '
#   '0.029*"attitude" + 0.024*"crime" + 0.022*"militant" + 0.022*"level" + '
#   '0.021*"muslim" + 0.021*"possibility"'),
#  (8,
#   '0.085*"sale" + 0.081*"deal" + 0.055*"consider" + 0.037*"stop" + '
#   '0.033*"appear" + 0.021*"production" + 0.017*"video_game" + 0.017*"software" '
#   '+ 0.015*"threaten" + 0.014*"communication"'),
#  (9,
#   '0.057*"accord" + 0.051*"number" + 0.049*"address" + 0.046*"area" + '
#   '0.042*"cost" + 0.042*"social" + 0.038*"need" + 0.035*"release" + '
#   '0.033*"oil" + 0.030*"budget"'),
#  (10,
#   '0.115*"possible" + 0.063*"right" + 0.060*"international" + '
#   '0.051*"operation" + 0.049*"risk" + 0.026*"figure" + 0.024*"human" + '
#   '0.016*"belief" + 0.012*"violation" + 0.007*"abandon"'),
#  (11,
#   '0.059*"follow" + 0.053*"economic" + 0.053*"police" + 0.045*"order" + '
#   '0.039*"go" + 0.035*"history" + 0.032*"allow" + 0.031*"propose" + '
#   '0.029*"officer" + 0.026*"influence"'),
#  (12,
#   '0.088*"security" + 0.057*"relation" + 0.049*"islamic" + 0.037*"allege" + '
#   '0.033*"intelligence" + 0.028*"suggest" + 0.025*"iranian" + '
#   '0.022*"allegedly" + 0.022*"advocate" + 0.020*"politician"'),
#  (13,
#   '0.074*"focus" + 0.052*"policy" + 0.044*"decision" + 0.041*"lack" + '
#   '0.040*"public" + 0.034*"support" + 0.027*"help" + 0.025*"attempt" + '
#   '0.021*"foreign" + 0.021*"family"'),
#  (14,
#   '0.058*"test" + 0.050*"search" + 0.049*"challenge" + 0.048*"building" + '
#   '0.034*"center" + 0.028*"donor" + 0.022*"fear" + 0.013*"infection" + '
#   '0.013*"adult" + 0.013*"letter"'),
#  (15,
#   '0.052*"term" + 0.051*"democratic" + 0.036*"house" + 0.034*"due" + '
#   '0.027*"fire" + 0.026*"department" + 0.024*"enough" + 0.022*"name" + '
#   '0.022*"study" + 0.019*"account"'),
#  (16,
#   '0.085*"student" + 0.074*"college" + 0.043*"health" + 0.040*"individual" + '
#   '0.032*"treatment" + 0.030*"decide" + 0.029*"investor" + 0.025*"score" + '
#   '0.023*"position" + 0.022*"racial"'),
#  (17,
#   '0.112*"say" + 0.081*"year" + 0.050*"member" + 0.047*"role" + 0.037*"kill" + '
#   '0.035*"call" + 0.034*"death" + 0.031*"involve" + 0.024*"information" + '
#   '0.020*"nation"'),
#  (18,
#   '0.088*"first" + 0.059*"day" + 0.053*"cut" + 0.052*"tax" + 0.045*"proposal" '
#   '+ 0.042*"team" + 0.036*"schedule" + 0.028*"taxis" + 0.021*"income" + '
#   '0.020*"hire"'),
#  (19,
#   '0.116*"topic" + 0.044*"month" + 0.041*"war" + 0.033*"long" + 0.030*"safety" '
#   '+ 0.028*"art" + 0.026*"care" + 0.026*"patient" + 0.023*"return" + '
#   '0.022*"serve"')]

# %% [markdown]
# Compute Model Perplexity and Coherence Score
# - Model perplexity and topic coherence provide a convenient measure to judge how good a given topic model is.
# - a quick explanation: https://rare-technologies.com/what-is-topic-coherence/
# - a paper: http://svn.aksw.org/papers/2015/WSDM_Topic_Evaluation/public.pdf

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -16.22100826944323
#
# Coherence Score:  0.37938913011142894

# %%
# # Visualize the topics
# pyLDAvis.enable_notebook()
# vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word,mds='mmds')
# vis

# %% [markdown]
# Each bubble on the left-hand side plot represents a topic. The larger the bubble, the more prevalent is that topic.
#
# - A good topic model will have fairly big, non-overlapping bubbles scattered throughout the chart instead of being clustered in one quadrant.
#
# - A model with too many topics, will typically have many overlaps, small sized bubbles clustered in one region of the chart.
#
# - if you move the cursor over one of the bubbles, the words and bars on the right-hand side will update. These words are the salient keywords that form the selected topic.
#
# - Given our prior knowledge of the number of natural topics in the document, finding the best model was fairly straightforward.
#
# Upnext, we will improve upon this model by using Mallet’s version of LDA algorithm and then we will focus on how to arrive at the optimal number of topics given any large corpus of text.

# %% [markdown]
# Mallet’s version, however, often gives a better quality of topics.
#
# Gensim provides a wrapper to implement Mallet’s LDA from within Gensim itself. You only need to download the zipfile, unzip it and provide the path to mallet in the unzipped directory to gensim.models.wrappers.LdaMallet.

# %%
# Building LDA Mallet Model
# Download File: http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
mallet_path = './mallet-2.0.8/bin/mallet'# update this path
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=20, id2word=id2word)

# %%
# Show Topics
pprint(ldamallet.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# [(5,
#   [('detail', 0.05801376597836775),
#    ('focus', 0.0535889872173058),
#    ('case', 0.051622418879056046),
#    ('decision', 0.048180924287118974),
#    ('view', 0.04375614552605703),
#    ('role', 0.03982300884955752),
#    ('comment', 0.035398230088495575),
#    ('involve', 0.023107177974434612),
#    ('information', 0.022123893805309734),
#    ('reaction', 0.02064896755162242)]),
#  (14,
#   [('year', 0.08258706467661692),
#    ('member', 0.04825870646766169),
#    ('end', 0.02935323383084577),
#    ('accord', 0.02935323383084577),
#    ('deal', 0.022885572139303482),
#    ('week', 0.022388059701492536),
#    ('remain', 0.021890547263681594),
#    ('budget', 0.020895522388059702),
#    ('spending', 0.020895522388059702),
#    ('agreement', 0.020398009950248756)]),
#  (6,
#   [('federal', 0.04903417533432392),
#    ('bill', 0.03268945022288262),
#    ('give', 0.03268945022288262),
#    ('debate', 0.02823179791976226),
#    ('money', 0.02526002971768202),
#    ('legislation', 0.02526002971768202),
#    ('measure', 0.02526002971768202),
#    ('agency', 0.0237741456166419),
#    ('question', 0.022783556215948488),
#    ('attempt', 0.020802377414561663)]),
#  (13,
#   [('state', 0.09769539078156313),
#    ('policy', 0.0531062124248497),
#    ('issue', 0.05260521042084168),
#    ('law', 0.052104208416833664),
#    ('group', 0.04609218436873747),
#    ('increase', 0.03507014028056112),
#    ('office', 0.02404809619238477),
#    ('tax', 0.023046092184368736),
#    ('require', 0.019539078156312624),
#    ('control', 0.01903807615230461)]),
#  (4,
#   [('include', 0.15532734274711169),
#    ('article', 0.13906718014548566),
#    ('discuss', 0.10226786478391099),
#    ('effort', 0.036799315361574665),
#    ('discusse', 0.03551561831407788),
#    ('topics_addresse', 0.03080872913992298),
#    ('regard', 0.030380830124090714),
#    ('impact', 0.029525032092426188),
#    ('note', 0.026957637997432605),
#    ('lack', 0.02396234488660676)]),
#  (16,
#   [('school', 0.03826530612244898),
#    ('student', 0.036734693877551024),
#    ('rule', 0.034183673469387756),
#    ('woman', 0.02857142857142857),
#    ('examine', 0.027551020408163266),
#    ('child', 0.027040816326530614),
#    ('court', 0.026530612244897958),
#    ('public', 0.026020408163265306),
#    ('raise', 0.02193877551020408),
#    ('college', 0.018367346938775512)]),
#  (3,
#   [('percent', 0.030061892130857647),
#    ('increase', 0.02961980548187445),
#    ('high', 0.028735632183908046),
#    ('economic', 0.028293545534924844),
#    ('market', 0.027409372236958444),
#    ('economy', 0.026967285587975242),
#    ('rise', 0.02564102564102564),
#    ('job', 0.022988505747126436),
#    ('price', 0.022546419098143235),
#    ('month', 0.019451812555260833)]),
#  (15,
#   [('military', 0.057638238050609185),
#    ('american', 0.05716963448922212),
#    ('force', 0.03889409559512652),
#    ('official', 0.03420805998125586),
#    ('war', 0.02717900656044986),
#    ('iraqi', 0.021087160262417994),
#    ('troop', 0.020618556701030927),
#    ('region', 0.018275538894095594),
#    ('follow', 0.018275538894095594),
#    ('send', 0.017338331771321464)]),
#  (11,
#   [('report', 0.12030456852791878),
#    ('government', 0.11269035532994924),
#    ('attack', 0.049238578680203045),
#    ('kill', 0.04010152284263959),
#    ('security', 0.03654822335025381),
#    ('response', 0.028426395939086295),
#    ('effort', 0.023857868020304568),
#    ('comment', 0.02030456852791878),
#    ('site', 0.016751269035532996),
#    ('speculation', 0.013197969543147208)]),
#  (0,
#   [('report', 0.051566265060240965),
#    ('official', 0.04433734939759036),
#    ('leader', 0.042409638554216866),
#    ('administration', 0.030843373493975902),
#    ('charge', 0.02650602409638554),
#    ('terrorist', 0.02650602409638554),
#    ('intelligence', 0.021204819277108433),
#    ('investigation', 0.021204819277108433),
#    ('action', 0.020240963855421686),
#    ('weapon', 0.019759036144578312)])]
#
# Coherence Score:  0.337944025779061

# %% [markdown]
# However, here afterchanging the LDA algorithm, the coherence score dropeed from .38 to .34.

# %% [markdown]
# To find the optimal number of topics for LDA?
# - build many LDA models with different values of number of topics (k) and pick the one that gives the highest coherence value.
#
# - Choosing a ‘k’ that marks the end of a rapid growth of topic coherence usually offers meaningful and interpretable topics. Picking an even higher value can sometimes provide more granular sub-topics.
#
# - If you see the same keywords being repeated in multiple topics, it’s probably a sign that the ‘k’ is too large.
#
# - The compute_coherence_values() (see below) trains multiple LDA models and provides the models and their corresponding coherence scores.

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=40, step=6)

# %%
# Show graph
limit=40; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# If the coherence score seems to keep increasing, it may make better sense to pick the model that gave the highest CV before flattening out. This is exactly the case here.
#
# So for further steps, here we choose the model with 20 topics (exactlt what we have gotten).

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.2428
# Num Topics = 8  has Coherence Value of 0.3432
# Num Topics = 14  has Coherence Value of 0.3351
# Num Topics = 20  has Coherence Value of 0.3299
# Num Topics = 26  has Coherence Value of 0.3317
# Num Topics = 32  has Coherence Value of 0.3406
# Num Topics = 38  has Coherence Value of 0.3401

# %% [markdown]
# Below are the topics for the chosen LDA model.

# %%
# Select the model and print the topics
optimal_model = model_list[3]
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.048*"member" + 0.038*"kill" + 0.030*"family" + 0.029*"death" + '
#   '0.027*"follow" + 0.025*"police" + 0.021*"involve" + 0.019*"detail" + '
#   '0.019*"effort" + 0.018*"control"'),
#  (1,
#   '0.113*"article" + 0.064*"discusse" + 0.042*"city" + 0.041*"include" + '
#   '0.039*"impact" + 0.033*"increase" + 0.023*"move" + 0.021*"oil" + '
#   '0.019*"area" + 0.018*"due"'),
#  (2,
#   '0.068*"make" + 0.055*"united_state" + 0.052*"public" + 0.036*"give" + '
#   '0.026*"nation" + 0.023*"deal" + 0.023*"claim" + 0.020*"weapon" + '
#   '0.017*"site" + 0.017*"nuclear"'),
#  (3,
#   '0.060*"report" + 0.056*"people" + 0.044*"service" + 0.036*"number" + '
#   '0.033*"find" + 0.025*"money" + 0.024*"provide" + 0.020*"receive" + '
#   '0.019*"offer" + 0.016*"expert"'),
#  (4,
#   '0.034*"increase" + 0.031*"bill" + 0.024*"cost" + 0.024*"measure" + '
#   '0.024*"legislation" + 0.023*"cut" + 0.023*"fund" + 0.022*"benefit" + '
#   '0.022*"tax" + 0.021*"large"'),
#  (5,
#   '0.082*"year" + 0.033*"day" + 0.030*"part" + 0.030*"end" + 0.025*"week" + '
#   '0.025*"leave" + 0.024*"accord" + 0.023*"early" + 0.022*"month" + '
#   '0.022*"remain"'),
#  (6,
#   '0.067*"report" + 0.042*"detail" + 0.039*"school" + 0.037*"student" + '
#   '0.032*"face" + 0.028*"child" + 0.026*"examine" + 0.019*"test" + '
#   '0.019*"college" + 0.018*"study"'),
#  (7,
#   '0.096*"report" + 0.064*"official" + 0.043*"plan" + 0.037*"security" + '
#   '0.035*"change" + 0.031*"administration" + 0.023*"agency" + '
#   '0.021*"investigation" + 0.021*"intelligence" + 0.015*"pressure"'),
#  (8,
#   '0.057*"company" + 0.029*"industry" + 0.028*"hold" + 0.028*"problem" + '
#   '0.024*"sale" + 0.021*"history" + 0.020*"action" + 0.018*"world" + '
#   '0.018*"insurance" + 0.017*"technology"'),
#  (9,
#   '0.058*"leader" + 0.056*"country" + 0.045*"political" + 0.026*"united_state" '
#   '+ 0.024*"place" + 0.020*"black" + 0.019*"term" + 0.017*"address" + '
#   '0.016*"implication" + 0.016*"business"'),
#  (10,
#   '0.031*"percent" + 0.030*"high" + 0.030*"economic" + 0.028*"market" + '
#   '0.028*"economy" + 0.027*"rise" + 0.025*"financial" + 0.023*"price" + '
#   '0.023*"job" + 0.020*"bank"'),
#  (11,
#   '0.053*"case" + 0.042*"group" + 0.028*"charge" + 0.024*"information" + '
#   '0.021*"suspect" + 0.019*"organization" + 0.018*"officer" + 0.017*"man" + '
#   '0.015*"trial" + 0.015*"evidence"'),
#  (12,
#   '0.082*"government" + 0.023*"grow" + 0.020*"result" + 0.019*"region" + '
#   '0.018*"worker" + 0.018*"risk" + 0.017*"report" + 0.016*"system" + '
#   '0.016*"foreign" + 0.016*"condition"'),
#  (13,
#   '0.059*"campaign" + 0.040*"election" + 0.036*"support" + 0.034*"republican" '
#   '+ 0.031*"bush" + 0.030*"candidate" + 0.029*"article" + 0.029*"vote" + '
#   '0.028*"voter" + 0.026*"democratic"'),
#  (14,
#   '0.103*"focus" + 0.046*"comment" + 0.041*"role" + 0.040*"view" + '
#   '0.028*"debate" + 0.027*"woman" + 0.026*"concern" + 0.025*"author" + '
#   '0.021*"question" + 0.021*"issue"'),
#  (15,
#   '0.090*"state" + 0.051*"federal" + 0.050*"policy" + 0.049*"law" + '
#   '0.038*"decision" + 0.031*"rule" + 0.026*"court" + 0.022*"issue" + '
#   '0.018*"require" + 0.016*"challenge"'),
#  (16,
#   '0.041*"time" + 0.036*"call" + 0.033*"drug" + 0.029*"order" + 0.025*"run" + '
#   '0.024*"team" + 0.020*"lead" + 0.020*"back" + 0.017*"national" + '
#   '0.017*"good"'),
#  (17,
#   '0.054*"military" + 0.052*"american" + 0.043*"attack" + 0.034*"force" + '
#   '0.031*"government" + 0.028*"iraqi" + 0.026*"war" + 0.024*"terrorist" + '
#   '0.024*"response" + 0.020*"troop"'),
#  (18,
#   '0.046*"work" + 0.031*"show" + 0.028*"program" + 0.021*"television" + '
#   '0.019*"announce" + 0.017*"live" + 0.016*"begin" + 0.016*"late" + '
#   '0.014*"project" + 0.014*"night"'),
#  (19,
#   '0.157*"article" + 0.134*"include" + 0.108*"discuss" + 0.055*"effort" + '
#   '0.031*"topics_addresse" + 0.029*"note" + 0.028*"regard" + 0.025*"lack" + '
#   '0.023*"topics_addressed" + 0.020*"potential"')]

# %% [markdown]
# Finding the dominant topic in each sentence
# - One of the practical application of topic modeling is to determine what topic a given document is about.
#
# - To find that, we find the topic number that has the highest percentage contribution in that document.
#
# - The format_topics_sentences() function below nicely aggregates this information in a presentable table.

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            17.0              0.1075
# 1            1             0.0              0.1133
# 2            2             0.0              0.1789
# 3            3            11.0              0.0998
# 4            4            17.0              0.0968
# 5            5            12.0              0.1104
# 6            6            17.0              0.1689
# 7            7             6.0              0.0902
# 8            8             6.0              0.1474
# 9            9            11.0              0.0758
#
#                                             Keywords  \
# 0  military, american, attack, force, government,...
# 1  member, kill, family, death, follow, police, i...
# 2  member, kill, family, death, follow, police, i...
# 3  case, group, charge, information, suspect, org...
# 4  military, american, attack, force, government,...
# 5  government, grow, result, region, worker, risk...
# 6  military, american, attack, force, government,...
# 7  report, detail, school, student, face, child, ...
# 8  report, detail, school, student, face, child, ...
# 9  case, group, charge, information, suspect, org...
#
#                                                 Text
# 0  focuses declaration war made united states pre...
# 1  reports air line pilots association largest pi...
# 2  focuses response dominicans americans crash am...
# 3  discusses testimony jamal ahmed alfadl secret ...
# 4  reports taliban government afghanistan announc...
# 5  reports two rival teams scientist presenting f...
# 6  reports palestinian leader yasir arafat instru...
# 7  reports new york citys teachers union abandoni...
# 8  examines nevada ranks near bottom states index...
# 9  reports united states presidentelect george w ...

# %% [markdown]
# Find the most representative document for each topic
# - Sometimes just the topic keywords may not be enough to make sense of what a topic is about.
# - To help with understanding the topic, you can find the documents a given topic has contributed to the most and infer the topic by reading that document.

# %%
#Find the most representative document for each topic
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet.head()
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.2920
# 1        1.0              0.2547
# 2        2.0              0.2449
# 3        3.0              0.2957
# 4        4.0              0.3121
#
#                                             Keywords  \
# 0  member, kill, family, death, follow, police, i...
# 1  article, discusse, city, include, impact, incr...
# 2  make, united_state, public, give, nation, deal...
# 3  report, people, service, number, find, money, ...
# 4  increase, bill, cost, measure, legislation, cu...
#
#                                                 Text
# 0  reports october th terrorist attack two discos...
# 1  article discusses trend increasing numbers evi...
# 2  reports north koreas warning catastrophe unite...
# 3  reports promoters atkins diet say people plan ...
# 4  international climate talks copenhagen preside...

# %% [markdown]
# Topic distribution across documents
# - To understand the volume and distribution of topics in order to judge how widely it was discussed.
# - The below table exposes that information.

# %%
#Topic distribution across documents
# Number of Documents for Each Topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# Show
df_dominant_topics
# Out:
#         Dominant_Topic                                     Topic_Keywords  \
# 0.0               17.0  military, american, attack, force, government,...
# 1.0                0.0  member, kill, family, death, follow, police, i...
# 2.0                0.0  member, kill, family, death, follow, police, i...
# 3.0               11.0  case, group, charge, information, suspect, org...
# 4.0               17.0  military, american, attack, force, government,...
# ...                ...                                                ...
# 1461.0            19.0  article, include, discuss, effort, topics_addr...
# 1462.0            18.0  work, show, program, television, announce, liv...
# 1463.0            13.0  campaign, election, support, republican, bush,...
# 1464.0             5.0  year, day, part, end, week, leave, accord, ear...
# 1465.0             1.0  article, discusse, city, include, impact, incr...
#
#         Num_Documents  Perc_Documents
# 0.0              78.0          0.0532
# 1.0              55.0          0.0375
# 2.0              60.0          0.0409
# 3.0              60.0          0.0409
# 4.0              87.0          0.0593
# ...               ...             ...
# 1461.0            NaN             NaN
# 1462.0            NaN             NaN
# 1463.0            NaN             NaN
# 1464.0            NaN             NaN
# 1465.0            NaN             NaN
#
# [1466 rows x 4 columns]

# %%
df_merge_col = pd.merge(df_dominant_topic, df, left_on='Text',right_on='Abstract')

# %%
df_merge_col
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0               0            17.0              0.1075
# 1               1             0.0              0.1133
# 2               2             0.0              0.1789
# 3               3            11.0              0.0998
# 4               4            17.0              0.0968
# ...           ...             ...                 ...
# 1461         1461            19.0              0.0860
# 1462         1462            18.0              0.0704
# 1463         1463            13.0              0.1484
# 1464         1464             5.0              0.0943
# 1465         1465             1.0              0.1103
#
#                                                Keywords  \
# 0     military, american, attack, force, government,...
# 1     member, kill, family, death, follow, police, i...
# 2     member, kill, family, death, follow, police, i...
# 3     case, group, charge, information, suspect, org...
# 4     military, american, attack, force, government,...
# ...                                                 ...
# 1461  article, include, discuss, effort, topics_addr...
# 1462  work, show, program, television, announce, liv...
# 1463  campaign, election, support, republican, bush,...
# 1464  year, day, part, end, week, leave, accord, ear...
# 1465  article, discusse, city, include, impact, incr...
#
#                                                    Text    News_id  Year  \
# 0     focuses declaration war made united states pre...    5158739  2001
# 1     reports air line pilots association largest pi...    5210808  2001
# 2     focuses response dominicans americans crash am...    5491991  2001
# 3     discusses testimony jamal ahmed alfadl secret ...    4056314  2001
# 4     reports taliban government afghanistan announc...    5240343  2001
# ...                                                 ...        ...   ...
# 1461  article discusses former us government agency ...  109431501  2015
# 1462  obituary physician howard w jones jr noted wor...  108686749  2015
# 1463  article discusses wisconsin governor scott wal...  102260584  2015
# 1464  article announces million people impacted hack...  103737745  2015
# 1465  article discusses eulogy delivered us presiden...  103447289  2015
#
#                                                   Title  \
# 0                                      long battle seen
# 1                      pilots ask permission carry guns
# 2                   grief echoes new york santo domingo
# 3     exaide bin laden describes terror campaign aim...
# 4         new push get bin laden agree quit afghanistan
# ...                                                 ...
# 1461                  lobbyist sixfigure government job
# 1462   physician pushed boundaries bring vitro birth us
# 1463                  pastors son runs faith iowa nears
# 1464         hacking exposed million us government says
# 1465         obama scorns racism soaring singing eulogy
#
#                                                Abstract
# 0     focuses declaration war made united states pre...
# 1     reports air line pilots association largest pi...
# 2     focuses response dominicans americans crash am...
# 3     discusses testimony jamal ahmed alfadl secret ...
# 4     reports taliban government afghanistan announc...
# ...                                                 ...
# 1461  article discusses former us government agency ...
# 1462  obituary physician howard w jones jr noted wor...
# 1463  article discusses wisconsin governor scott wal...
# 1464  article announces million people impacted hack...
# 1465  article discusses eulogy delivered us presiden...
#
# [1466 rows x 9 columns]

# %%
df_merge_col.to_csv('dominant_topic_news_20_topics.csv')
